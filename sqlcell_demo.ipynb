# %% [markdown]
# # SQLCell 2.0: Redesigning `SQLCell` for JupyterLab

# %% [markdown]
# I've been meaning to revisit <a href="https://github.com/tmthyjames/SQLCell">SQLCell</a> for some time. Besides the codebase being a product of my early days of learning how to program and that making contributions was cumbersome due to the poor design of the API, the real force behind me refactoring was that I've been using Jupyter Lab a lot lately and I still hate most SQL interfaces. I like the freedom of being able to use Jupyter as a pseudo-SQL app—there's not as much functionality as a fully fledged SQL interface, but for most of my needs, I just need to write queries; I don't need the same level of utility as a DBA would.
#
# Therefore, I'm refactoring SQLCell completely to work with both Jupyter Notebook and Jupyter Lab. The major differences in this release are:
#
#     1) No UI buttons or graphs (yet)
#     2) The API is a lot cleaner
#
# Back in the day of Jupyter Notebooks, you could publish a notebook that injected malicious Javascript onto a user's computer. Now, <a href="https://jupyter-notebook.readthedocs.io/en/stable/examples/Notebook/JavaScript%20Notebook%20Extensions.html">that is no longer (publicly) possible</a>. I say public, because there's not a public Javascript API for Lab like there is for Notebook. This comes with its benefits and costs, as is reflected in many Github conversations (<a href="https://github.com/jupyterlab/jupyterlab/issues/3118">here</a> and <a href="https://github.com/jupyterlab/jupyterlab/issues/3748">here</a> and <a href="https://github.com/jupyterlab/jupyterlab/pull/2595">here</a>). With that, I am still looking into building graphs and UI features into a future version. And hopefully this release will attract more contributors as the API is much cleaner than version 1's.
#
# Here are the features I'm starting with:
#
# >### [Engine Persistence](#Engine-Persistence)
#
# >### [Python Variables as Query Parameters](#Python-Variables-as-Query-Parameters)
#
# >### [Engine Aliasing](#Engine-Aliasing)
#
# >### [Defining and Persisting Hooks](#Defining-and-Persisting-Hooks)
#
# >### [Write SQL Output to Session Variable](#Write-SQL-Output-to-Session-Variable)
#
# >### [Background Queries](#Background-Queries)
#
# To install SQLCell use `pip`:

# %% [raw]
# pip install sqlcell

# %% [markdown]
# Then load it in your Notebook/Lab by using the `%load_ext` command:

# %%
# %load_ext sqlcell.sqlcell

# %% [markdown]
# ## Engine Persistence

# %% [markdown]
# The first time you use `%%sql`, you'll need to pass your connection string as an `--engine` argument.

# %%
# %%sql --engine=mssql+pymssql://SomeUser:SomePassword@180.36.3.100/tdobbins
#
# SELECT TOP 2 N1.*
# FROM NashvilleHousingMSSQL N1
# JOIN NashvilleHousingMSSQL N2 ON N2.ParcelID = N1.ParcelID
# ORDER BY Address DESC
# Out:
#    Acreage       Address Bedrooms  BuildingValue       City ExteriorWall  \
# 0     0.11  804  LENA ST     None            0.0  NASHVILLE         None
# 1     0.11  804  LENA ST     None            0.0  NASHVILLE         None
#
#   FinishedArea FoundationType FullBath Grade  ... SalePrice SoldAsVacant  \
# 0         None           None     None  None  ...     16000           No
# 1         None           None     None  None  ...     16000           No
#
#    State Suite/Condo#              TaxDistrict  TotalValue Unnamed:0  \
# 0     TN         None  URBAN SERVICES DISTRICT      9000.0        87
# 1     TN         None  URBAN SERVICES DISTRICT      9000.0        87
#
#   Unnamed:0.1 YearBuilt image
# 0          87      None  None
# 1          87      None  None
#
# [2 rows x 31 columns]

# %% [markdown]
# After that, SQLCell will create a few aliases for you to easily refer to the engine you're wanting to run against. Now you can pass the entire connection string or either the hostname or the database name, and `%%sql` will use the same engine for all three. Note, if you have two databases with the same name, consider just using the hostname.

# %%
# %%sql --engine=180.36.3.100
#
# SELECT TOP 2 *
# FROM NashvilleHousingMSSQL
# Out:
#    Acreage           Address  Bedrooms  BuildingValue       City ExteriorWall  \
# 0     0.76  5316  OVERTON RD       4.0       300400.0  NASHVILLE        BRICK
# 1      NaN              None       NaN            NaN       None         None
#
#    FinishedArea FoundationType  FullBath Grade  ...  SalePrice SoldAsVacant  \
# 0        2370.0      FULL BSMT       2.0  B     ...     267300           No
# 1           NaN           None       NaN  None  ...     207000           No
#
#    State Suite/Condo#              TaxDistrict  TotalValue Unnamed:0  \
# 0     TN         None  URBAN SERVICES DISTRICT    355400.0        24
# 1   None         None                     None         NaN        59
#
#   Unnamed:0.1 YearBuilt               image
# 0          24    1968.0  \184000\836001.JPG
# 1          59       NaN                None
#
# [2 rows x 31 columns]

# %% [markdown]
# `%%sql` will also remember the last used engine so you don't have to refer to it everytime you run a query.

# %%
# %%sql
#
# SELECT TOP 2 *
# FROM NashvilleHousingMSSQL
# Out:
#    Acreage           Address  Bedrooms  BuildingValue       City ExteriorWall  \
# 0     0.76  5316  OVERTON RD       4.0       300400.0  NASHVILLE        BRICK
# 1      NaN              None       NaN            NaN       None         None
#
#    FinishedArea FoundationType  FullBath Grade  ...  SalePrice SoldAsVacant  \
# 0        2370.0      FULL BSMT       2.0  B     ...     267300           No
# 1           NaN           None       NaN  None  ...     207000           No
#
#    State Suite/Condo#              TaxDistrict  TotalValue Unnamed:0  \
# 0     TN         None  URBAN SERVICES DISTRICT    355400.0        24
# 1   None         None                     None         NaN        59
#
#   Unnamed:0.1 YearBuilt               image
# 0          24    1968.0  \184000\836001.JPG
# 1          59       NaN                None
#
# [2 rows x 31 columns]

# %% [markdown]
# ## Python Variables as Query Parameters

# %% [markdown]
# If you want to pass Python variables to your query, you can use the colon (`foo = :foo`) syntax (similar to SQLAlchemy's usage).

# %%
foo = 'NASHVILLE'
bar = 132000
baz = ('SINGLE FAMILY', 'RESIDENTIAL CONDO')

# %%
# %%sql --engine=180.36.3.100
#
# select *
# from NashvilleHousingMSSQL
# where PropertyCity = :foo
#     and SalePrice like :bar
#     and LandUse in :baz
# Out:
#   Acreage Address Bedrooms BuildingValue  City ExteriorWall FinishedArea  \
# 0    None    None     None          None  None         None         None
# 1    None    None     None          None  None         None         None
#
#   FoundationType FullBath Grade  ... SalePrice SoldAsVacant State  \
# 0           None     None  None  ...    132000           No  None
# 1           None     None  None  ...    132000           No  None
#
#   Suite/Condo# TaxDistrict TotalValue Unnamed:0 Unnamed:0.1 YearBuilt image
# 0            8        None       None       0.0         0.0      None  None
# 1            8        None       None       NaN         NaN      None  None
#
# [2 rows x 31 columns]

# %% [markdown]
# And the same with a Postgres dialect:

# %%
foo = 'NASHVILLE'
bar = 132000
baz = ('SINGLE FAMILY', 'RESIDENTIAL CONDO')

# %%
# %%sql --engine=PG
# select n2.*
# from "NashvilleHousingPostgres" n1
# JOIN "NashvilleHousingPostgres" n2 on n2."ParcelID" = n1."ParcelID"
# where n2."PropertyCity" = :foo
#     and n2."SalePrice" = :bar
#     and n2."LandUse" in :baz
# Out:
#   Acreage Address Bedrooms BuildingValue  City ExteriorWall FinishedArea  \
# 0    None    None     None          None  None         None         None
#
#   FoundationType FullBath Grade  ... PropertyCity    SaleDate SalePrice  \
# 0           None     None  None  ...    NASHVILLE  2013-01-24    132000
#
#   SoldAsVacant State Suite/Condo# TaxDistrict TotalValue YearBuilt image
# 0           No  None            8        None       None      None  None
#
# [1 rows x 29 columns]

# %% [markdown]
# ## Engine Aliasing

# %% [markdown]
# Similar to <a href="https://github.com/tmthyjames/SQLCell#declare-engines">version 1</a>, you can also alias engine strings. Unlike version 1, there are no UI buttons (yet). Using the following syntax:

# %%
# %%sql --engines
#
# PG=postgresql://dbuser:@localhost/dbuser
#
# MSS=mssql+pymssql://SomeUser:SomePassword@180.36.3.100/tdobbins
#
# LC=mssql+pymssql://username:password@180.36.3.100/DB1
# Out:
# 'Engines successfully registered'

# %% [markdown]
# we can now use `%%sql` with an alias as our `--engine` parameter:

# %%
# %%sql --engine=MSS
#
# select top 2 * from NashvilleHousingMSSQL
# Out:
#    Acreage           Address  Bedrooms  BuildingValue       City ExteriorWall  \
# 0     0.76  5316  OVERTON RD       4.0       300400.0  NASHVILLE        BRICK
# 1      NaN              None       NaN            NaN       None         None
#
#    FinishedArea FoundationType  FullBath Grade  ...  SalePrice SoldAsVacant  \
# 0        2370.0      FULL BSMT       2.0  B     ...     267300           No
# 1           NaN           None       NaN  None  ...     207000           No
#
#    State Suite/Condo#              TaxDistrict  TotalValue Unnamed:0  \
# 0     TN         None  URBAN SERVICES DISTRICT    355400.0        24
# 1   None         None                     None         NaN        59
#
#   Unnamed:0.1 YearBuilt               image
# 0          24    1968.0  \184000\836001.JPG
# 1          59       NaN                None
#
# [2 rows x 31 columns]

# %% [markdown]
# To view all your engines, use the `list` argument:

# %%
# %%sql --engines
# list
# Out:
#   Alias                                             Engine
# 0    PG          postgresql://dbuser:@localhost/dbuser
# 1   MSS  mssql+pymssql://SomeUser:SomePassword@17...
# 2    LC  mssql+pymssql://username:password@180.36.3.10...

# %% [markdown]
# To clear your engines, use the `--refresh` command like so:

# %%
# %%sql --refresh
# engines
# Out:
# 'Removed all records from engines'

# %% [markdown]
# ## Defining and Persisting Hooks

# %% [markdown]
# One thing I tried to do with version 1 is mimic `psql` commands (since I was using postgres exclusively), but doing that forced limitations on users who used other DBs. With this version, I'm removing those limitations by allowing users to register their own often-run shortcut queries like so:

# %%
# %%sql --hook
#
# tables MSS = USE {0};
# SELECT * FROM sys.Tables;
#
# columns_mss MSS = EXEC sp_columns {0};
#
# columns_db1 DB1 = EXEC sp_columns {0};
#
# views mssql+pymssql://username:password@hostname/DB = USE {0};
# SELECT * FROM sys.Views;
#
# tables_db1 DB1 = USE {0};
# SELECT * FROM sys.Tables;
#
# views_l mssql+pymssql://:@localhost/DB = USE {0};
# SELECT * FROM sys.Views;
#
# databases LC = SELECT name FROM master.sys.databases;
# Out:
# 'Hook successfully registered'

# %% [markdown]
# The syntax for defining hooks is:
#
# > ```
# <name> <engine|alias> = <sql command>```
#
# Take this example:
#
# >```
# tables MSS = USE {0};
# SELECT * FROM sys.Tables;
# ```
#
# where
#
# `tables` is our command shortcut.
#
# `MSS` is an engine alias we have already defined with `--engines`.
#
# and
#
# ```
# USE {0};
# SELECT * FROM sys.Tables;
# ```
#
# is the comand we want to run when we issue our shortcut.
#
# To use your newly-defined shortcuts, prepend `~` to your shortcut name:

# %%
# %%sql
# ~columns_mss NashvilleHousingMSSQL
# Out:
#     CHAR_OCTET_LENGTH COLUMN_DEF                    COLUMN_NAME  DATA_TYPE  \
# 0                 NaN       None                      Unnamed:0         -5
# 1                 NaN       None                    Unnamed:0.1         -5
# 2        2.147484e+09       None                       ParcelID         -1
# 3        2.147484e+09       None                        LandUse         -1
# 4        2.147484e+09       None                PropertyAddress         -1
# 5        2.147484e+09       None                   Suite/Condo#         -1
# 6        2.147484e+09       None                   PropertyCity         -1
# 7        2.147484e+09       None                       SaleDate         -1
# 8                 NaN       None                      SalePrice         -5
# 9        2.147484e+09       None                 LegalReference         -1
# 10       2.147484e+09       None                   SoldAsVacant         -1
# 11       2.147484e+09       None  MultipleParcelsInvolvedinSale         -1
# 12       2.147484e+09       None                      OwnerName         -1
# 13       2.147484e+09       None                        Address         -1
# 14       2.147484e+09       None                           City         -1
# 15       2.147484e+09       None                          State         -1
# 16                NaN       None                        Acreage          6
# 17       2.147484e+09       None                    TaxDistrict         -1
# 18                NaN       None                   Neighborhood          6
# 19       2.147484e+09       None                          image         -1
# 20                NaN       None                      LandValue          6
# 21                NaN       None                  BuildingValue          6
# 22                NaN       None                     TotalValue          6
# 23                NaN       None                   FinishedArea          6
# 24       2.147484e+09       None                 FoundationType         -1
# 25                NaN       None                      YearBuilt          6
# 26       2.147484e+09       None                   ExteriorWall         -1
# 27       2.147484e+09       None                          Grade         -1
# 28                NaN       None                       Bedrooms          6
# 29                NaN       None                       FullBath          6
# 30                NaN       None                       HalfBath          6
#
#    IS_NULLABLE      LENGTH  NULLABLE  ORDINAL_POSITION   PRECISION  RADIX  \
# 0          YES           8         1                 1          19   10.0
# 1          YES           8         1                 2          19   10.0
# 2          YES  2147483647         1                 3  2147483647    NaN
# 3          YES  2147483647         1                 4  2147483647    NaN
# 4          YES  2147483647         1                 5  2147483647    NaN
# 5          YES  2147483647         1                 6  2147483647    NaN
# 6          YES  2147483647         1                 7  2147483647    NaN
# 7          YES  2147483647         1                 8  2147483647    NaN
# 8          YES           8         1                 9          19   10.0
# 9          YES  2147483647         1                10  2147483647    NaN
# 10         YES  2147483647         1                11  2147483647    NaN
# 11         YES  2147483647         1                12  2147483647    NaN
# 12         YES  2147483647         1                13  2147483647    NaN
# 13         YES  2147483647         1                14  2147483647    NaN
# 14         YES  2147483647         1                15  2147483647    NaN
# 15         YES  2147483647         1                16  2147483647    NaN
# 16         YES           8         1                17          15   10.0
# 17         YES  2147483647         1                18  2147483647    NaN
# 18         YES           8         1                19          15   10.0
# 19         YES  2147483647         1                20  2147483647    NaN
# 20         YES           8         1                21          15   10.0
# 21         YES           8         1                22          15   10.0
# 22         YES           8         1                23          15   10.0
# 23         YES           8         1                24          15   10.0
# 24         YES  2147483647         1                25  2147483647    NaN
# 25         YES           8         1                26          15   10.0
# 26         YES  2147483647         1                27  2147483647    NaN
# 27         YES  2147483647         1                28  2147483647    NaN
# 28         YES           8         1                29          15   10.0
# 29         YES           8         1                30          15   10.0
# 30         YES           8         1                31          15   10.0
#
#    REMARKS  SCALE  SQL_DATA_TYPE SQL_DATETIME_SUB  SS_DATA_TYPE  \
# 0     None    0.0             -5             None           108
# 1     None    0.0             -5             None           108
# 2     None    NaN             -1             None            39
# 3     None    NaN             -1             None            39
# 4     None    NaN             -1             None            39
# 5     None    NaN             -1             None            39
# 6     None    NaN             -1             None            39
# 7     None    NaN             -1             None            39
# 8     None    0.0             -5             None           108
# 9     None    NaN             -1             None            39
# 10    None    NaN             -1             None            39
# 11    None    NaN             -1             None            39
# 12    None    NaN             -1             None            39
# 13    None    NaN             -1             None            39
# 14    None    NaN             -1             None            39
# 15    None    NaN             -1             None            39
# 16    None    NaN              6             None           109
# 17    None    NaN             -1             None            39
# 18    None    NaN              6             None           109
# 19    None    NaN             -1             None            39
# 20    None    NaN              6             None           109
# 21    None    NaN              6             None           109
# 22    None    NaN              6             None           109
# 23    None    NaN              6             None           109
# 24    None    NaN             -1             None            39
# 25    None    NaN              6             None           109
# 26    None    NaN             -1             None            39
# 27    None    NaN             -1             None            39
# 28    None    NaN              6             None           109
# 29    None    NaN              6             None           109
# 30    None    NaN              6             None           109
#
#                TABLE_NAME TABLE_OWNER TABLE_QUALIFIER TYPE_NAME
# 0   NashvilleHousingMSSQL         dbo        tdobbins    bigint
# 1   NashvilleHousingMSSQL         dbo        tdobbins    bigint
# 2   NashvilleHousingMSSQL         dbo        tdobbins      text
# 3   NashvilleHousingMSSQL         dbo        tdobbins      text
# 4   NashvilleHousingMSSQL         dbo        tdobbins      text
# 5   NashvilleHousingMSSQL         dbo        tdobbins      text
# 6   NashvilleHousingMSSQL         dbo        tdobbins      text
# 7   NashvilleHousingMSSQL         dbo        tdobbins      text
# 8   NashvilleHousingMSSQL         dbo        tdobbins    bigint
# 9   NashvilleHousingMSSQL         dbo        tdobbins      text
# 10  NashvilleHousingMSSQL         dbo        tdobbins      text
# 11  NashvilleHousingMSSQL         dbo        tdobbins      text
# 12  NashvilleHousingMSSQL         dbo        tdobbins      text
# 13  NashvilleHousingMSSQL         dbo        tdobbins      text
# 14  NashvilleHousingMSSQL         dbo        tdobbins      text
# 15  NashvilleHousingMSSQL         dbo        tdobbins      text
# 16  NashvilleHousingMSSQL         dbo        tdobbins     float
# 17  NashvilleHousingMSSQL         dbo        tdobbins      text
# 18  NashvilleHousingMSSQL         dbo        tdobbins     float
# 19  NashvilleHousingMSSQL         dbo        tdobbins      text
# 20  NashvilleHousingMSSQL         dbo        tdobbins     float
# 21  NashvilleHousingMSSQL         dbo        tdobbins     float
# 22  NashvilleHousingMSSQL         dbo        tdobbins     float
# 23  NashvilleHousingMSSQL         dbo        tdobbins     float
# 24  NashvilleHousingMSSQL         dbo        tdobbins      text
# 25  NashvilleHousingMSSQL         dbo        tdobbins     float
# 26  NashvilleHousingMSSQL         dbo        tdobbins      text
# 27  NashvilleHousingMSSQL         dbo        tdobbins      text
# 28  NashvilleHousingMSSQL         dbo        tdobbins     float
# 29  NashvilleHousingMSSQL         dbo        tdobbins     float
# 30  NashvilleHousingMSSQL         dbo        tdobbins     float

# %% [markdown]
# Since we defined `columns_mss` as having an argument, `{0}`, we can pass a table name to it.

# %% [markdown]
# To view your hooks, use `list`:

# %%
# %%sql --hook
# list
# Out:
#          Alias                                             Engine  \
# 0       tables  mssql+pymssql://SomeUser:SomePassword@17...
# 1  columns_mss  mssql+pymssql://SomeUser:SomePassword@17...
# 2  columns_db1  mssql+pymssql://username:password@180.36.3.10...
# 3        views  mssql+pymssql://username:password@180.36.3.10...
# 4   tables_db1  mssql+pymssql://username:password@180.36.3.10...
# 5      views_l                    mssql+pymssql://:@localhost/DB1
# 6    databases  mssql+pymssql://username:password@180.36.3.10...
#
#                                      Hook
# 0     USE {0};\nSELECT * FROM sys.Tables;
# 1                    EXEC sp_columns {0};
# 2                    EXEC sp_columns {0};
# 3      USE {0};\nSELECT * FROM sys.Views;
# 4     USE {0};\nSELECT * FROM sys.Tables;
# 5      USE {0};\nSELECT * FROM sys.Views;
# 6  SELECT name FROM master.sys.databases;

# %% [markdown]
# And to clear your hook list, just run `--refresh` with `hooks` as the cell content, like we did for engines:

# %%
# %%sql --refresh
# hooks
# Out:
# 'Removed all records from hooks'

# %% [markdown]
# ## Write SQL Output to Session Variable

# %% [markdown]
# To write the output of your query to a Python variable, use the `--var` argument.

# %%
# %%sql --engine=LC --var=df
# select 1 as some_lc_column
# Out:
#    some_lc_column
# 0               1

# %%
df
# Out:
#    some_lc_column
# 0               1

# %% [markdown]
# ## Background Queries

# %% [markdown]
# To run queries in the background, use the `--background` flag:

# %%
# %%sql --engine=LC --var=another_df --background
# select 1 as some_lc_column

# %% [markdown]
# Notice here that `another_df` is undefined since the query is still running:

# %%
another_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-135decb41fec> in <module>
# ----> 1 another_df
#
# NameError: name 'another_df' is not defined

# %% [markdown]
# As soon as the query is done, you can call `another_df` successfully.

# %%
another_df
# Out:
#    some_lc_column
# 0               1

# %% [markdown]
# I'm working on a way to notify the user when a query finishes in the background. I'm also working on adding UI buttons using ipywidgets. Enjoy!
